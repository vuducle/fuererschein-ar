# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %%
import os
import re
import requests
from bs4 import BeautifulSoup

# URL of the page to scrape
url = "https://www.dvr.de/service/verkehrszeichen"

# Send a GET request to the website
response = requests.get(url)

# Function to sanitize filenames
def sanitize_filename(filename):
    # Remove or replace invalid characters
    return re.sub(r'[\\/*?:"<>|]', "", filename)

# Function to download images
def download_image(img_url, title, downloaded_files):
    # Get the image content
    img_response = requests.get(img_url)
    if img_response.status_code == 200:
        # Create a sanitized filename by replacing spaces with underscores
        sanitized_title = sanitize_filename(title.replace(' ', '_'))
        filename = f"{sanitized_title}.png"
        if filename not in downloaded_files:
            # Write the image content to a file
            with open(filename, 'wb') as img_file:
                img_file.write(img_response.content)
            downloaded_files.add(filename)
            print(f"Downloaded {filename}")
        else:
            print(f"Skipping duplicate file {filename}")
    else:
        print(f"Failed to download image {img_url}")

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Set to keep track of downloaded files
    downloaded_files = set()

    # Find all 'a' elements with 'href' and 'title' attributes
    a_elements = soup.find_all('a', href=True, title=True)

    for a in a_elements:
        # Extract the href and title attributes
        href = a['href']
        title = a['title']

        # Check if the href is a link to a verkehrszeichen image
        if "/fileadmin/downloads/verkehrszeichen/" in href:
            # Construct the full image URL
            img_url = f"https://www.dvr.de{href}"
            # Download the image
            download_image(img_url, title, downloaded_files)
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# Downloaded Zeichen_101_Gefahrstelle.png
# Skipping duplicate file Zeichen_101_Gefahrstelle.png
# Skipping duplicate file Zeichen_101_Gefahrstelle.png
# Downloaded Zeichen_102_Kreuzung_oder_Einmündung.png
# Skipping duplicate file Zeichen_102_Kreuzung_oder_Einmündung.png
# Skipping duplicate file Zeichen_102_Kreuzung_oder_Einmündung.png
# Downloaded Zeichen_103_Kurve.png
# Skipping duplicate file Zeichen_103_Kurve.png
# Skipping duplicate file Zeichen_103_Kurve.png
# Downloaded Zeichen_105_Doppelkurve_.png
# Skipping duplicate file Zeichen_105_Doppelkurve_.png
# Skipping duplicate file Zeichen_105_Doppelkurve_.png
# Downloaded Zeichen_108_Gefälle_.png
# Skipping duplicate file Zeichen_108_Gefälle_.png
# Skipping duplicate file Zeichen_108_Gefälle_.png
# Downloaded Zeichen_110_Steigung_.png
# Skipping duplicate file Zeichen_110_Steigung_.png
# Skipping duplicate file Zeichen_110_Steigung_.png
# Downloaded Zeichen_112_Unebene_Fahrbahn.png
# Skipping duplicate file Zeichen_112_Unebene_Fahrbahn.png
# Skipping duplicate file Zeichen_112_Unebene_Fahrbahn.png
# Downloaded Zeichen_114_Schleuder-_oder_Rutschgefahr.png
# Skipping duplicate file Zeichen_114_Schleuder-_oder_Rutschgefahr.png
# Skipping duplicate file Zeichen_114_Schleuder-_oder_Rutschgefahr.png
# Downloaded Zeichen_117_Seitenwind.png
# Skipping duplicate file Zeichen_117_Seitenwind.png
# Skipping duplicate file Zeichen_117_Seitenwind.png
# Downloaded Zeichen_120_Verengte_Fahrbahn.png
# Skipping duplicate file Zeichen_120_Verengte_Fahrbahn.png
# Skipping duplicate file Zeichen_120_Verengte_Fahrbahn.png
# Downloaded Zeichen_121_Einseitig_verengte_Fahrbahn.png
# Skipping duplicate file Zeichen_121_Einseitig_verengte_Fahrbahn.png
# Skipping duplicate file Zeichen_121_Einseitig_verengte_Fahrbahn.png
# Downloaded Zeichen_123_Arbeitsstelle_.png
# Skipping duplicate file Zeichen_123_Arbeitsstelle_.png
# Skipping duplicate file Zeichen_123_Arbeitsstelle_.png
# Downloaded Zeichen_124_Stau_.png
# Skipping duplicate file Zeichen_124_Stau_.png
# Skipping duplicate file Zeichen_124_Stau_.png
# Downloaded Zeichen_125_Gegenverkehr_.png
# Skipping duplicate file Zeichen_125_Gegenverkehr_.png
# Skipping duplicate file Zeichen_125_Gegenverkehr_.png
# Downloaded Zeichen_131_Lichtzeichenanlage.png
# Skipping duplicate file Zeichen_131_Lichtzeichenanlage.png
# Skipping duplicate file Zeichen_131_Lichtzeichenanlage.png
# Downloaded Zeichen_133_Fußgänger_.png
# Skipping duplicate file Zeichen_133_Fußgänger_.png
# Skipping duplicate file Zeichen_133_Fußgänger_.png
# Downloaded Zeichen_136_Kinder_.png
# Skipping duplicate file Zeichen_136_Kinder_.png
# Skipping duplicate file Zeichen_136_Kinder_.png
# Downloaded Zeichen_138_Radverkehr.png
# Skipping duplicate file Zeichen_138_Radverkehr.png
# Skipping duplicate file Zeichen_138_Radverkehr.png
# Downloaded Zeichen_142_Wildwechsel.png
# Skipping duplicate file Zeichen_142_Wildwechsel.png
# Skipping duplicate file Zeichen_142_Wildwechsel.png
# Downloaded Zeichen_151_Bahnübergang_.png
# Skipping duplicate file Zeichen_151_Bahnübergang_.png
# Skipping duplicate file Zeichen_151_Bahnübergang_.png
# Downloaded Zeichen_156_Bahnübergang_mit_dreistreifiger_Bake.png
# Skipping duplicate file Zeichen_156_Bahnübergang_mit_dreistreifiger_Bake.png
# Skipping duplicate file Zeichen_156_Bahnübergang_mit_dreistreifiger_Bake.png
# Downloaded Zeichen_159_Zweistreifige_Bake.png
# Skipping duplicate file Zeichen_159_Zweistreifige_Bake.png
# Skipping duplicate file Zeichen_159_Zweistreifige_Bake.png
# Downloaded Zeichen_162_Einstreifige_Bake_.png
# Skipping duplicate file Zeichen_162_Einstreifige_Bake_.png
# Skipping duplicate file Zeichen_162_Einstreifige_Bake_.png
# Downloaded Zeichen_201_Andreaskreuz_.png
# Skipping duplicate file Zeichen_201_Andreaskreuz_.png
# Skipping duplicate file Zeichen_201_Andreaskreuz_.png
# Downloaded Zeichen_205_Vorfahrt_gewähren.png
# Skipping duplicate file Zeichen_205_Vorfahrt_gewähren.png
# Skipping duplicate file Zeichen_205_Vorfahrt_gewähren.png
# Downloaded Zeichen_206_Halt._Vorfahrt_gewähren_.png
# Skipping duplicate file Zeichen_206_Halt._Vorfahrt_gewähren_.png
# Skipping duplicate file Zeichen_206_Halt._Vorfahrt_gewähren_.png
# Downloaded Zeichen_208_Vorrang_des_Gegenverkehrs.png
# Skipping duplicate file Zeichen_208_Vorrang_des_Gegenverkehrs.png
# Skipping duplicate file Zeichen_208_Vorrang_des_Gegenverkehrs.png
# Downloaded Zeichen_209_Rechts_.png
# Skipping duplicate file Zeichen_209_Rechts_.png
# Skipping duplicate file Zeichen_209_Rechts_.png
# Downloaded Zeichen_211_Hier_rechts.png
# Skipping duplicate file Zeichen_211_Hier_rechts.png
# Skipping duplicate file Zeichen_211_Hier_rechts.png
# Downloaded Zeichen_214_Geradeaus_oder_rechts.png
# Skipping duplicate file Zeichen_214_Geradeaus_oder_rechts.png
# Skipping duplicate file Zeichen_214_Geradeaus_oder_rechts.png
# Downloaded Zeichen_215_Kreisverkehr_.png
# Skipping duplicate file Zeichen_215_Kreisverkehr_.png
# Skipping duplicate file Zeichen_215_Kreisverkehr_.png
# Downloaded Zeichen_220_Einbahnstraße_.png
# Skipping duplicate file Zeichen_220_Einbahnstraße_.png
# Skipping duplicate file Zeichen_220_Einbahnstraße_.png
# Downloaded Zeichen_222_Rechts_vorbei.png
# Skipping duplicate file Zeichen_222_Rechts_vorbei.png
# Skipping duplicate file Zeichen_222_Rechts_vorbei.png
# Downloaded Zeichen_223.1_Seitenstreifen_befahren_.png
# Skipping duplicate file Zeichen_223.1_Seitenstreifen_befahren_.png
# Skipping duplicate file Zeichen_223.1_Seitenstreifen_befahren_.png
# Downloaded Zeichen_223.2_Seitenstreifen_nicht_mehr_befahren.png
# Skipping duplicate file Zeichen_223.2_Seitenstreifen_nicht_mehr_befahren.png
# Skipping duplicate file Zeichen_223.2_Seitenstreifen_nicht_mehr_befahren.png
# Downloaded Zeichen_223.3_Seitenstreifen_räumen_.png
# Skipping duplicate file Zeichen_223.3_Seitenstreifen_räumen_.png
# Skipping duplicate file Zeichen_223.3_Seitenstreifen_räumen_.png
# Downloaded Zeichen_224_Haltestelle_.png
# Skipping duplicate file Zeichen_224_Haltestelle_.png
# Skipping duplicate file Zeichen_224_Haltestelle_.png
# Downloaded Zeichen_229_Taxenstand_.png
# Skipping duplicate file Zeichen_229_Taxenstand_.png
# Skipping duplicate file Zeichen_229_Taxenstand_.png
# Downloaded Zeichen_237_Radweg_.png
# Skipping duplicate file Zeichen_237_Radweg_.png
# Skipping duplicate file Zeichen_237_Radweg_.png
# Downloaded Zeichen_238_Reitweg_.png
# Skipping duplicate file Zeichen_238_Reitweg_.png
# Skipping duplicate file Zeichen_238_Reitweg_.png
# Downloaded Zeichen_239_Gehweg_.png
# Skipping duplicate file Zeichen_239_Gehweg_.png
# Skipping duplicate file Zeichen_239_Gehweg_.png
# Downloaded Zeichen_240_Gemeinsamer_Geh-_und_Radweg.png
# Skipping duplicate file Zeichen_240_Gemeinsamer_Geh-_und_Radweg.png
# Skipping duplicate file Zeichen_240_Gemeinsamer_Geh-_und_Radweg.png
# Downloaded Zeichen_241_Getrennter_Rad-_und_Gehweg_.png
# Skipping duplicate file Zeichen_241_Getrennter_Rad-_und_Gehweg_.png
# Skipping duplicate file Zeichen_241_Getrennter_Rad-_und_Gehweg_.png
# Downloaded Zeichen_242.1_Beginn_einer_Fußgängerzone_.png
# Skipping duplicate file Zeichen_242.1_Beginn_einer_Fußgängerzone_.png
# Skipping duplicate file Zeichen_242.1_Beginn_einer_Fußgängerzone_.png
# Downloaded Zeichen_242.2_Ende_einer_Fußgängerzone_.png
# Skipping duplicate file Zeichen_242.2_Ende_einer_Fußgängerzone_.png
# Skipping duplicate file Zeichen_242.2_Ende_einer_Fußgängerzone_.png
# Downloaded Zeichen_244.1_Beginn_einer_Fahrradstraße_.png
# Skipping duplicate file Zeichen_244.1_Beginn_einer_Fahrradstraße_.png
# Skipping duplicate file Zeichen_244.1_Beginn_einer_Fahrradstraße_.png
# Downloaded Zeichen_244.2_Ende_einer_Fahrradstraße.png
# Skipping duplicate file Zeichen_244.2_Ende_einer_Fahrradstraße.png
# Skipping duplicate file Zeichen_244.2_Ende_einer_Fahrradstraße.png
# Downloaded Zeichen_244.3_Beginn_einer_Fahrradzone.png
# Skipping duplicate file Zeichen_244.3_Beginn_einer_Fahrradzone.png
# Skipping duplicate file Zeichen_244.3_Beginn_einer_Fahrradzone.png
# Downloaded Zeichen_244.4_Ende_einer_Fahrradzone_.png
# Skipping duplicate file Zeichen_244.4_Ende_einer_Fahrradzone_.png
# Skipping duplicate file Zeichen_244.4_Ende_einer_Fahrradzone_.png
# Downloaded Zeichen_245_Bussonderfahrstreifen_.png
# Skipping duplicate file Zeichen_245_Bussonderfahrstreifen_.png
# Skipping duplicate file Zeichen_245_Bussonderfahrstreifen_.png
# Downloaded Zeichen_250_Verbot_für_Fahrzeuge_aller_Art_.png
# Skipping duplicate file Zeichen_250_Verbot_für_Fahrzeuge_aller_Art_.png
# Skipping duplicate file Zeichen_250_Verbot_für_Fahrzeuge_aller_Art_.png
# Downloaded Zeichen_251_Verbot_für_Kraftwagen.png
# Skipping duplicate file Zeichen_251_Verbot_für_Kraftwagen.png
# Skipping duplicate file Zeichen_251_Verbot_für_Kraftwagen.png
# Downloaded Zeichen_253_Verbot_für_Kraft­fahrzeuge_über_3,5_t.png
# Skipping duplicate file Zeichen_253_Verbot_für_Kraft­fahrzeuge_über_3,5_t.png
# Skipping duplicate file Zeichen_253_Verbot_für_Kraft­fahrzeuge_über_3,5_t.png
# Downloaded Zeichen_254_Verbot_für_Radverkehr_.png
# Skipping duplicate file Zeichen_254_Verbot_für_Radverkehr_.png
# Skipping duplicate file Zeichen_254_Verbot_für_Radverkehr_.png
# Downloaded Zeichen_255_Verbot_für_Krafträder_.png
# Skipping duplicate file Zeichen_255_Verbot_für_Krafträder_.png
# Skipping duplicate file Zeichen_255_Verbot_für_Krafträder_.png
# Downloaded Zeichen_259_Verbot_für_Fußgänger.png
# Skipping duplicate file Zeichen_259_Verbot_für_Fußgänger.png
# Skipping duplicate file Zeichen_259_Verbot_für_Fußgänger.png
# Downloaded Zeichen_260_Verbot_für_Kraftfahrzeuge.png
# Skipping duplicate file Zeichen_260_Verbot_für_Kraftfahrzeuge.png
# Skipping duplicate file Zeichen_260_Verbot_für_Kraftfahrzeuge.png
# Downloaded Zeichen_261_Verbot_für_kenn­zeichnungs­pflichtige_Kraft­fahr­zeuge_mit_gefährlichen_Gütern.png
# Skipping duplicate file Zeichen_261_Verbot_für_kenn­zeichnungs­pflichtige_Kraft­fahr­zeuge_mit_gefährlichen_Gütern.png
# Skipping duplicate file Zeichen_261_Verbot_für_kenn­zeichnungs­pflichtige_Kraft­fahr­zeuge_mit_gefährlichen_Gütern.png
# Downloaded Zeichen_262_Tatsächliche_Masse_.png
# Skipping duplicate file Zeichen_262_Tatsächliche_Masse_.png
# Skipping duplicate file Zeichen_262_Tatsächliche_Masse_.png
# Downloaded Zeichen_263_Tatsächliche_Achslast.png
# Skipping duplicate file Zeichen_263_Tatsächliche_Achslast.png
# Skipping duplicate file Zeichen_263_Tatsächliche_Achslast.png
# Downloaded Zeichen_264_Tatsächliche_Breite.png
# Skipping duplicate file Zeichen_264_Tatsächliche_Breite.png
# Skipping duplicate file Zeichen_264_Tatsächliche_Breite.png
# Downloaded Zeichen_265_Tatsächliche_Höhe_.png
# Skipping duplicate file Zeichen_265_Tatsächliche_Höhe_.png
# Skipping duplicate file Zeichen_265_Tatsächliche_Höhe_.png
# Downloaded Zeichen_266_Tatsächliche_Länge.png
# Skipping duplicate file Zeichen_266_Tatsächliche_Länge.png
# Skipping duplicate file Zeichen_266_Tatsächliche_Länge.png
# Downloaded Zeichen_267_Verbot_der_Einfahrt.png
# Skipping duplicate file Zeichen_267_Verbot_der_Einfahrt.png
# Skipping duplicate file Zeichen_267_Verbot_der_Einfahrt.png
# Downloaded Zeichen_268_Schneeketten_vorgeschrieben.png
# Skipping duplicate file Zeichen_268_Schneeketten_vorgeschrieben.png
# Skipping duplicate file Zeichen_268_Schneeketten_vorgeschrieben.png
# Downloaded Zeichen_269_Verbot_für_Fahr­zeuge_mit_wasser­gefähr­dender_Ladung.png
# Skipping duplicate file Zeichen_269_Verbot_für_Fahr­zeuge_mit_wasser­gefähr­dender_Ladung.png
# Skipping duplicate file Zeichen_269_Verbot_für_Fahr­zeuge_mit_wasser­gefähr­dender_Ladung.png
# Downloaded Zeichen_270.1_Beginn_einer_Verkehrs­verbotszone_zur_Verminderung_schädlicher_Luftverunreinigungen_in_einer_Zone.png
# Skipping duplicate file Zeichen_270.1_Beginn_einer_Verkehrs­verbotszone_zur_Verminderung_schädlicher_Luftverunreinigungen_in_einer_Zone.png
# Skipping duplicate file Zeichen_270.1_Beginn_einer_Verkehrs­verbotszone_zur_Verminderung_schädlicher_Luftverunreinigungen_in_einer_Zone.png
# Downloaded Zeichen_270.2_Ende_einer_Verkehrsverbotszone_zur_Verminderung_schädlicher_Luftverunreinigungen_in_einer_Zone_.png
# Skipping duplicate file Zeichen_270.2_Ende_einer_Verkehrsverbotszone_zur_Verminderung_schädlicher_Luftverunreinigungen_in_einer_Zone_.png
# Skipping duplicate file Zeichen_270.2_Ende_einer_Verkehrsverbotszone_zur_Verminderung_schädlicher_Luftverunreinigungen_in_einer_Zone_.png
# Downloaded Zeichen_272_Verbot_des_Wendens.png
# Skipping duplicate file Zeichen_272_Verbot_des_Wendens.png
# Skipping duplicate file Zeichen_272_Verbot_des_Wendens.png
# Downloaded Zeichen_273_Verbot_des_Unterschreitens_des_angegebenen_Mindestabstandes.png
# Skipping duplicate file Zeichen_273_Verbot_des_Unterschreitens_des_angegebenen_Mindestabstandes.png
# Skipping duplicate file Zeichen_273_Verbot_des_Unterschreitens_des_angegebenen_Mindestabstandes.png
# Downloaded Zeichen_274_Zuläs­sige_Höchst­ge­schwin­dig­keit.png
# Skipping duplicate file Zeichen_274_Zuläs­sige_Höchst­ge­schwin­dig­keit.png
# Skipping duplicate file Zeichen_274_Zuläs­sige_Höchst­ge­schwin­dig­keit.png
# Downloaded Zeichen_274.1_Beginn_einer_Tempo_30-Zone.png
# Skipping duplicate file Zeichen_274.1_Beginn_einer_Tempo_30-Zone.png
# Skipping duplicate file Zeichen_274.1_Beginn_einer_Tempo_30-Zone.png
# Downloaded Zeichen_274.2_Ende_einer_Tempo_30-Zone_.png
# Skipping duplicate file Zeichen_274.2_Ende_einer_Tempo_30-Zone_.png
# Skipping duplicate file Zeichen_274.2_Ende_einer_Tempo_30-Zone_.png
# Downloaded Zeichen_275_Vorgeschriebene_Mindest­geschwin­dig­keit.png
# Skipping duplicate file Zeichen_275_Vorgeschriebene_Mindest­geschwin­dig­keit.png
# Skipping duplicate file Zeichen_275_Vorgeschriebene_Mindest­geschwin­dig­keit.png
# Downloaded Zeichen_276_Überhol­verbot_für_Kraft­fahr­zeuge_aller_Art.png
# Skipping duplicate file Zeichen_276_Überhol­verbot_für_Kraft­fahr­zeuge_aller_Art.png
# Skipping duplicate file Zeichen_276_Überhol­verbot_für_Kraft­fahr­zeuge_aller_Art.png
# Downloaded Zeichen_277_Überholverbot_für_Kraftfahrzeuge_über_3,5_t_.png
# Skipping duplicate file Zeichen_277_Überholverbot_für_Kraftfahrzeuge_über_3,5_t_.png
# Skipping duplicate file Zeichen_277_Überholverbot_für_Kraftfahrzeuge_über_3,5_t_.png
# Downloaded Zeichen_277.1_Verbot_des_Überholens_von_einspurigen_Fahrzeugen_für_mehrspurige_Kraftfahrzeuge_und_Krafträdern_mit_Beiwagen.png
# Skipping duplicate file Zeichen_277.1_Verbot_des_Überholens_von_einspurigen_Fahrzeugen_für_mehrspurige_Kraftfahrzeuge_und_Krafträdern_mit_Beiwagen.png
# Skipping duplicate file Zeichen_277.1_Verbot_des_Überholens_von_einspurigen_Fahrzeugen_für_mehrspurige_Kraftfahrzeuge_und_Krafträdern_mit_Beiwagen.png
# Downloaded Zeichen_278_Ende_der_zuläs­sigen_Höchst­ge­schwin­dig­keit_.png
# Skipping duplicate file Zeichen_278_Ende_der_zuläs­sigen_Höchst­ge­schwin­dig­keit_.png
# Skipping duplicate file Zeichen_278_Ende_der_zuläs­sigen_Höchst­ge­schwin­dig­keit_.png
# Downloaded Zeichen_279_Ende_der_vor­ge­schriebenen_Mindest­geschwin­digkeit.png
# Skipping duplicate file Zeichen_279_Ende_der_vor­ge­schriebenen_Mindest­geschwin­digkeit.png
# Skipping duplicate file Zeichen_279_Ende_der_vor­ge­schriebenen_Mindest­geschwin­digkeit.png
# Downloaded Zeichen_280_Ende_des_Überhol­verbots_für_Kraft­fahr­zeuge_aller_Art_.png
# Skipping duplicate file Zeichen_280_Ende_des_Überhol­verbots_für_Kraft­fahr­zeuge_aller_Art_.png
# Skipping duplicate file Zeichen_280_Ende_des_Überhol­verbots_für_Kraft­fahr­zeuge_aller_Art_.png
# Downloaded Zeichen_281_Ende_des_Überholverbots_für_Kraftfahrzeuge_über_3,5_t_.png
# Skipping duplicate file Zeichen_281_Ende_des_Überholverbots_für_Kraftfahrzeuge_über_3,5_t_.png
# Skipping duplicate file Zeichen_281_Ende_des_Überholverbots_für_Kraftfahrzeuge_über_3,5_t_.png
# Downloaded Zeichen_281.1_Ende_des_Verbots_des_Überholens_von_einspurigen_Fahrzeugen_für_mehrspurige_Kraftfahrzeuge_und_Krafträdern_mit_Beiwagen.png
# Skipping duplicate file Zeichen_281.1_Ende_des_Verbots_des_Überholens_von_einspurigen_Fahrzeugen_für_mehrspurige_Kraftfahrzeuge_und_Krafträdern_mit_Beiwagen.png
# Skipping duplicate file Zeichen_281.1_Ende_des_Verbots_des_Überholens_von_einspurigen_Fahrzeugen_für_mehrspurige_Kraftfahrzeuge_und_Krafträdern_mit_Beiwagen.png
# Downloaded Zeichen_282_Ende_sämtlicher_streckenbezogener_Geschwindigkeits­beschränkungen_und_Überholverbote.png
# Skipping duplicate file Zeichen_282_Ende_sämtlicher_streckenbezogener_Geschwindigkeits­beschränkungen_und_Überholverbote.png
# Skipping duplicate file Zeichen_282_Ende_sämtlicher_streckenbezogener_Geschwindigkeits­beschränkungen_und_Überholverbote.png
# Downloaded Zeichen_283_Absolutes_Haltverbot_.png
# Skipping duplicate file Zeichen_283_Absolutes_Haltverbot_.png
# Skipping duplicate file Zeichen_283_Absolutes_Haltverbot_.png
# Downloaded Zeichen_286_Ein­ge­schränktes_Haltverbot.png
# Skipping duplicate file Zeichen_286_Ein­ge­schränktes_Haltverbot.png
# Skipping duplicate file Zeichen_286_Ein­ge­schränktes_Haltverbot.png
# Downloaded Zeichen_290.1_Beginn_eines_Eingeschränkten_Haltverbots_für_eine_Zone.png
# Skipping duplicate file Zeichen_290.1_Beginn_eines_Eingeschränkten_Haltverbots_für_eine_Zone.png
# Skipping duplicate file Zeichen_290.1_Beginn_eines_Eingeschränkten_Haltverbots_für_eine_Zone.png
# Downloaded Zeichen_290.2_Ende_eines_eingeschränkten_Haltverbotes_für_eine_Zone_.png
# Skipping duplicate file Zeichen_290.2_Ende_eines_eingeschränkten_Haltverbotes_für_eine_Zone_.png
# Skipping duplicate file Zeichen_290.2_Ende_eines_eingeschränkten_Haltverbotes_für_eine_Zone_.png
# Downloaded Zeichen_293_Fußgängerüberweg.png
# Skipping duplicate file Zeichen_293_Fußgängerüberweg.png
# Skipping duplicate file Zeichen_293_Fußgängerüberweg.png
# Downloaded Zeichen_294_Haltlinie_.png
# Skipping duplicate file Zeichen_294_Haltlinie_.png
# Skipping duplicate file Zeichen_294_Haltlinie_.png
# Downloaded Zeichen_295_Fahrstreifen­begrenzung_und_Fahrbahn­begrenzung.png
# Skipping duplicate file Zeichen_295_Fahrstreifen­begrenzung_und_Fahrbahn­begrenzung.png
# Skipping duplicate file Zeichen_295_Fahrstreifen­begrenzung_und_Fahrbahn­begrenzung.png
# Downloaded Zeichen_296_(Fahrstreifen_B__Fahrstreifen_A)_Einseitige_Fahr­streifen­begrenzung.png
# Skipping duplicate file Zeichen_296_(Fahrstreifen_B__Fahrstreifen_A)_Einseitige_Fahr­streifen­begrenzung.png
# Skipping duplicate file Zeichen_296_(Fahrstreifen_B__Fahrstreifen_A)_Einseitige_Fahr­streifen­begrenzung.png
# Downloaded Zeichen_297_Pfeilmarkierungen.png
# Skipping duplicate file Zeichen_297_Pfeilmarkierungen.png
# Skipping duplicate file Zeichen_297_Pfeilmarkierungen.png
# Downloaded Zeichen_297.1_Vorankündigungspfeil.png
# Skipping duplicate file Zeichen_297.1_Vorankündigungspfeil.png
# Skipping duplicate file Zeichen_297.1_Vorankündigungspfeil.png
# Downloaded Zeichen_298_Sperrfläche_.png
# Skipping duplicate file Zeichen_298_Sperrfläche_.png
# Skipping duplicate file Zeichen_298_Sperrfläche_.png
# Downloaded Zeichen_299_Grenzmarkierung_für_Halt-_oder_Park­verbote_.png
# Skipping duplicate file Zeichen_299_Grenzmarkierung_für_Halt-_oder_Park­verbote_.png
# Skipping duplicate file Zeichen_299_Grenzmarkierung_für_Halt-_oder_Park­verbote_.png
# Downloaded Zeichen_301_Vorfahrt_.png
# Skipping duplicate file Zeichen_301_Vorfahrt_.png
# Skipping duplicate file Zeichen_301_Vorfahrt_.png
# Downloaded Zeichen_306_Vorfahrtstraße.png
# Skipping duplicate file Zeichen_306_Vorfahrtstraße.png
# Skipping duplicate file Zeichen_306_Vorfahrtstraße.png
# Downloaded Zeichen_307_Ende_der_Vorfahrt­straße.png
# Skipping duplicate file Zeichen_307_Ende_der_Vorfahrt­straße.png
# Skipping duplicate file Zeichen_307_Ende_der_Vorfahrt­straße.png
# Downloaded Zeichen_308_Vorrang_vor_dem_Gegenverkehr.png
# Skipping duplicate file Zeichen_308_Vorrang_vor_dem_Gegenverkehr.png
# Skipping duplicate file Zeichen_308_Vorrang_vor_dem_Gegenverkehr.png
# Downloaded Zeichen_310_Ortstafel_Vorderseite.png
# Skipping duplicate file Zeichen_310_Ortstafel_Vorderseite.png
# Skipping duplicate file Zeichen_310_Ortstafel_Vorderseite.png
# Downloaded Zeichen_311_Ortstafel_Rückseite_.png
# Skipping duplicate file Zeichen_311_Ortstafel_Rückseite_.png
# Skipping duplicate file Zeichen_311_Ortstafel_Rückseite_.png
# Downloaded Zeichen_314_Parken.png
# Skipping duplicate file Zeichen_314_Parken.png
# Skipping duplicate file Zeichen_314_Parken.png
# Downloaded Zeichen_314.1_Beginn_einer_Parkraum-bewirtschaftungszone.png
# Skipping duplicate file Zeichen_314.1_Beginn_einer_Parkraum-bewirtschaftungszone.png
# Skipping duplicate file Zeichen_314.1_Beginn_einer_Parkraum-bewirtschaftungszone.png
# Downloaded Zeichen_314.2_Ende_einer_Parkraum-bewirtschaftungszone.png
# Skipping duplicate file Zeichen_314.2_Ende_einer_Parkraum-bewirtschaftungszone.png
# Skipping duplicate file Zeichen_314.2_Ende_einer_Parkraum-bewirtschaftungszone.png
# Downloaded Zeichen_315_Parken_auf_Gehwegen.png
# Skipping duplicate file Zeichen_315_Parken_auf_Gehwegen.png
# Skipping duplicate file Zeichen_315_Parken_auf_Gehwegen.png
# Downloaded Bild_318_Parkscheibe_.png
# Skipping duplicate file Bild_318_Parkscheibe_.png
# Skipping duplicate file Bild_318_Parkscheibe_.png
# Downloaded Zeichen_325.1_Beginn_eines_ver­kehrs­beruhigten_Bereichs.png
# Skipping duplicate file Zeichen_325.1_Beginn_eines_ver­kehrs­beruhigten_Bereichs.png
# Skipping duplicate file Zeichen_325.1_Beginn_eines_ver­kehrs­beruhigten_Bereichs.png
# Downloaded Zeichen_325.2_Ende_eines_ver­kehrs­beruhigten_Bereichs_.png
# Skipping duplicate file Zeichen_325.2_Ende_eines_ver­kehrs­beruhigten_Bereichs_.png
# Skipping duplicate file Zeichen_325.2_Ende_eines_ver­kehrs­beruhigten_Bereichs_.png
# Downloaded Zeichen_327_Tunnel.png
# Skipping duplicate file Zeichen_327_Tunnel.png
# Skipping duplicate file Zeichen_327_Tunnel.png
# Downloaded Zeichen_328_Nothalte-_und_Pannenbucht.png
# Skipping duplicate file Zeichen_328_Nothalte-_und_Pannenbucht.png
# Skipping duplicate file Zeichen_328_Nothalte-_und_Pannenbucht.png
# Downloaded Zeichen_330.1_Autobahn_.png
# Skipping duplicate file Zeichen_330.1_Autobahn_.png
# Skipping duplicate file Zeichen_330.1_Autobahn_.png
# Downloaded Zeichen_330.2_Ende_der_Autobahn_.png
# Skipping duplicate file Zeichen_330.2_Ende_der_Autobahn_.png
# Skipping duplicate file Zeichen_330.2_Ende_der_Autobahn_.png
# Downloaded Zeichen_331.1_Kraftfahrstraße_.png
# Skipping duplicate file Zeichen_331.1_Kraftfahrstraße_.png
# Skipping duplicate file Zeichen_331.1_Kraftfahrstraße_.png
# Downloaded Zeichen_331.2_Ende_der_Kraftfahrstraße.png
# Skipping duplicate file Zeichen_331.2_Ende_der_Kraftfahrstraße.png
# Skipping duplicate file Zeichen_331.2_Ende_der_Kraftfahrstraße.png
# Downloaded Zeichen_333_Ausfahrt_von_der_Autobahn.png
# Skipping duplicate file Zeichen_333_Ausfahrt_von_der_Autobahn.png
# Skipping duplicate file Zeichen_333_Ausfahrt_von_der_Autobahn.png
# Downloaded Zeichen_450_Ankündigungsbake_.png
# Skipping duplicate file Zeichen_450_Ankündigungsbake_.png
# Skipping duplicate file Zeichen_450_Ankündigungsbake_.png
# Downloaded Zeichen_340_Leitlinie_.png
# Skipping duplicate file Zeichen_340_Leitlinie_.png
# Skipping duplicate file Zeichen_340_Leitlinie_.png
# Downloaded Zeichen_341_Wartelinie.png
# Skipping duplicate file Zeichen_341_Wartelinie.png
# Skipping duplicate file Zeichen_341_Wartelinie.png
# Downloaded Zeichen_342_Haifischzähne.png
# Skipping duplicate file Zeichen_342_Haifischzähne.png
# Skipping duplicate file Zeichen_342_Haifischzähne.png
# Downloaded Zeichen_350_Fuß­gänger­über­weg.png
# Skipping duplicate file Zeichen_350_Fuß­gänger­über­weg.png
# Skipping duplicate file Zeichen_350_Fuß­gänger­über­weg.png
# Downloaded Zeichen_350.1_Radschnellweg.png
# Skipping duplicate file Zeichen_350.1_Radschnellweg.png
# Skipping duplicate file Zeichen_350.1_Radschnellweg.png
# Downloaded Zeichen_350.2_Ende_des_Radschnellwegs.png
# Skipping duplicate file Zeichen_350.2_Ende_des_Radschnellwegs.png
# Skipping duplicate file Zeichen_350.2_Ende_des_Radschnellwegs.png
# Downloaded Zeichen_354_Wasser­schutz­gebiet.png
# Skipping duplicate file Zeichen_354_Wasser­schutz­gebiet.png
# Skipping duplicate file Zeichen_354_Wasser­schutz­gebiet.png
# Downloaded Zeichen_356_Verkehrshelfer.png
# Skipping duplicate file Zeichen_356_Verkehrshelfer.png
# Skipping duplicate file Zeichen_356_Verkehrshelfer.png
# Downloaded Zeichen_357_Sackgasse.png
# Skipping duplicate file Zeichen_357_Sackgasse.png
# Skipping duplicate file Zeichen_357_Sackgasse.png
# Downloaded Zeichen_358_Erste_Hilfe_.png
# Skipping duplicate file Zeichen_358_Erste_Hilfe_.png
# Skipping duplicate file Zeichen_358_Erste_Hilfe_.png
# Downloaded Zeichen_363_Polizei_.png
# Skipping duplicate file Zeichen_363_Polizei_.png
# Skipping duplicate file Zeichen_363_Polizei_.png
# Downloaded Zeichen_385_Ortshinweistafel_.png
# Skipping duplicate file Zeichen_385_Ortshinweistafel_.png
# Skipping duplicate file Zeichen_385_Ortshinweistafel_.png
# Downloaded Zeichen_386.1_Touristischer_Hinweis.png
# Skipping duplicate file Zeichen_386.1_Touristischer_Hinweis.png
# Skipping duplicate file Zeichen_386.1_Touristischer_Hinweis.png
# Downloaded Zeichen_386.2_Touristischer_Route_.png
# Skipping duplicate file Zeichen_386.2_Touristischer_Route_.png
# Skipping duplicate file Zeichen_386.2_Touristischer_Route_.png
# Downloaded Zeichen_386.3_Touristische_Unterrichtungstafel.png
# Skipping duplicate file Zeichen_386.3_Touristische_Unterrichtungstafel.png
# Skipping duplicate file Zeichen_386.3_Touristische_Unterrichtungstafel.png
# Downloaded Zeichen_390_Mautpflicht_nach_dem_Bundesfern­straßen­mautgesetz.png
# Skipping duplicate file Zeichen_390_Mautpflicht_nach_dem_Bundesfern­straßen­mautgesetz.png
# Skipping duplicate file Zeichen_390_Mautpflicht_nach_dem_Bundesfern­straßen­mautgesetz.png
# Downloaded Zeichen_391_Mautpflichtige_Strecke_.png
# Skipping duplicate file Zeichen_391_Mautpflichtige_Strecke_.png
# Skipping duplicate file Zeichen_391_Mautpflichtige_Strecke_.png
# Downloaded Zeichen_392_Zollstelle_.png
# Skipping duplicate file Zeichen_392_Zollstelle_.png
# Skipping duplicate file Zeichen_392_Zollstelle_.png
# Downloaded Zeichen_393_Informations­tafel_an_Grenz­über­gangs­stellen.png
# Skipping duplicate file Zeichen_393_Informations­tafel_an_Grenz­über­gangs­stellen.png
# Skipping duplicate file Zeichen_393_Informations­tafel_an_Grenz­über­gangs­stellen.png
# Downloaded Zeichen_394_Laternenring.png
# Skipping duplicate file Zeichen_394_Laternenring.png
# Skipping duplicate file Zeichen_394_Laternenring.png
# Downloaded Zeichen_401_Bundesstraßen_.png
# Skipping duplicate file Zeichen_401_Bundesstraßen_.png
# Skipping duplicate file Zeichen_401_Bundesstraßen_.png
# Downloaded Zeichen_405_Autobahnen_.png
# Skipping duplicate file Zeichen_405_Autobahnen_.png
# Skipping duplicate file Zeichen_405_Autobahnen_.png
# Downloaded Zeichen_406_Knotenpunkte_der_Autobahnen.png
# Skipping duplicate file Zeichen_406_Knotenpunkte_der_Autobahnen.png
# Skipping duplicate file Zeichen_406_Knotenpunkte_der_Autobahnen.png
# Downloaded Zeichen_410_Europastraßen_.png
# Skipping duplicate file Zeichen_410_Europastraßen_.png
# Skipping duplicate file Zeichen_410_Europastraßen_.png
# Downloaded Zeichen_438_Vorwegweiser_außerhalb_von_Autobahnen_.png
# Skipping duplicate file Zeichen_438_Vorwegweiser_außerhalb_von_Autobahnen_.png
# Skipping duplicate file Zeichen_438_Vorwegweiser_außerhalb_von_Autobahnen_.png
# Downloaded Zeichen_439_Gegliederter_Vorwegweiser_außerhalb_von_Autobahnen.png
# Skipping duplicate file Zeichen_439_Gegliederter_Vorwegweiser_außerhalb_von_Autobahnen.png
# Skipping duplicate file Zeichen_439_Gegliederter_Vorwegweiser_außerhalb_von_Autobahnen.png
# Downloaded Zeichen_440_Vorwegweiser_zur_Autobahn_.png
# Skipping duplicate file Zeichen_440_Vorwegweiser_zur_Autobahn_.png
# Skipping duplicate file Zeichen_440_Vorwegweiser_zur_Autobahn_.png
# Downloaded Zeichen_441_Gegliederter_Vorwegweiser_zur_Autobahn_.png
# Skipping duplicate file Zeichen_441_Gegliederter_Vorwegweiser_zur_Autobahn_.png
# Skipping duplicate file Zeichen_441_Gegliederter_Vorwegweiser_zur_Autobahn_.png
# Downloaded Zeichen_415_Pfeilwegweiser_auf_Bundesstraßen_.png
# Skipping duplicate file Zeichen_415_Pfeilwegweiser_auf_Bundesstraßen_.png
# Skipping duplicate file Zeichen_415_Pfeilwegweiser_auf_Bundesstraßen_.png
# Downloaded Zeichen_418_Pfeilwegweiser_auf_sonstigen_Straßen.png
# Skipping duplicate file Zeichen_418_Pfeilwegweiser_auf_sonstigen_Straßen.png
# Skipping duplicate file Zeichen_418_Pfeilwegweiser_auf_sonstigen_Straßen.png
# Downloaded Zeichen_419_Pfeilwegweiser_auf_sonstigen_Straßen_mit_geringerer_Verkehrs­bedeutung.png
# Skipping duplicate file Zeichen_419_Pfeilwegweiser_auf_sonstigen_Straßen_mit_geringerer_Verkehrs­bedeutung.png
# Skipping duplicate file Zeichen_419_Pfeilwegweiser_auf_sonstigen_Straßen_mit_geringerer_Verkehrs­bedeutung.png
# Downloaded Zeichen_430_Pfeilwegweiser_zur_Autobahn_.png
# Skipping duplicate file Zeichen_430_Pfeilwegweiser_zur_Autobahn_.png
# Skipping duplicate file Zeichen_430_Pfeilwegweiser_zur_Autobahn_.png
# Downloaded Zeichen_432_Pfeilwegweiser_zu_Zielen_mit_erheblicher_Verkehrs­bedeutung.png
# Skipping duplicate file Zeichen_432_Pfeilwegweiser_zu_Zielen_mit_erheblicher_Verkehrs­bedeutung.png
# Skipping duplicate file Zeichen_432_Pfeilwegweiser_zu_Zielen_mit_erheblicher_Verkehrs­bedeutung.png
# Downloaded Zeichen_434_Tabellenwegweiser_.png
# Skipping duplicate file Zeichen_434_Tabellenwegweiser_.png
# Skipping duplicate file Zeichen_434_Tabellenwegweiser_.png
# Downloaded Zeichen_332.1_Ausfahrt_von_der_Autobahn.png
# Skipping duplicate file Zeichen_332.1_Ausfahrt_von_der_Autobahn.png
# Skipping duplicate file Zeichen_332.1_Ausfahrt_von_der_Autobahn.png
# Downloaded Zeichen_437_Straßennamens­schild.png
# Skipping duplicate file Zeichen_437_Straßennamens­schild.png
# Skipping duplicate file Zeichen_437_Straßennamens­schild.png
# Downloaded Zeichen_448_Ankündigungs­tafel_.png
# Skipping duplicate file Zeichen_448_Ankündigungs­tafel_.png
# Skipping duplicate file Zeichen_448_Ankündigungs­tafel_.png
# Downloaded Zeichen_448.1_Autohof_.png
# Skipping duplicate file Zeichen_448.1_Autohof_.png
# Skipping duplicate file Zeichen_448.1_Autohof_.png
# Downloaded Zeichen_449_Vorwegweiser_auf_Autobahnen_.png
# Skipping duplicate file Zeichen_449_Vorwegweiser_auf_Autobahnen_.png
# Skipping duplicate file Zeichen_449_Vorwegweiser_auf_Autobahnen_.png
# Downloaded Zeichen_332_Ausfahrttafel_auf_der_Autobahn.png
# Skipping duplicate file Zeichen_332_Ausfahrttafel_auf_der_Autobahn.png
# Skipping duplicate file Zeichen_332_Ausfahrttafel_auf_der_Autobahn.png
# Downloaded Zeichen_453_Entfernungstafel_.png
# Skipping duplicate file Zeichen_453_Entfernungstafel_.png
# Skipping duplicate file Zeichen_453_Entfernungstafel_.png
# Downloaded Zeichen_442_Vorwegweiser_für_bestimmte_Verkehrsarten.png
# Skipping duplicate file Zeichen_442_Vorwegweiser_für_bestimmte_Verkehrsarten.png
# Skipping duplicate file Zeichen_442_Vorwegweiser_für_bestimmte_Verkehrsarten.png
# Downloaded Zeichen_421_Pfeilwegweiser_für_bestimmte_Verkehrsarten.png
# Skipping duplicate file Zeichen_421_Pfeilwegweiser_für_bestimmte_Verkehrsarten.png
# Skipping duplicate file Zeichen_421_Pfeilwegweiser_für_bestimmte_Verkehrsarten.png
# Downloaded Zeichen_422_Wegweiser_für_bestimmte_Verkehrsarten.png
# Skipping duplicate file Zeichen_422_Wegweiser_für_bestimmte_Verkehrsarten.png
# Skipping duplicate file Zeichen_422_Wegweiser_für_bestimmte_Verkehrsarten.png
# Downloaded Zeichen_454_Umleitungs­wegweiser_.png
# Skipping duplicate file Zeichen_454_Umleitungs­wegweiser_.png
# Skipping duplicate file Zeichen_454_Umleitungs­wegweiser_.png
# Downloaded Zeichen_455.1_Ankündigung_oder_Fortsetzung_der_Umleitung_.png
# Skipping duplicate file Zeichen_455.1_Ankündigung_oder_Fortsetzung_der_Umleitung_.png
# Skipping duplicate file Zeichen_455.1_Ankündigung_oder_Fortsetzung_der_Umleitung_.png
# Downloaded Zeichen_457.1_Umleitungs­ankündigung.png
# Skipping duplicate file Zeichen_457.1_Umleitungs­ankündigung.png
# Skipping duplicate file Zeichen_457.1_Umleitungs­ankündigung.png
# Downloaded Zeichen_458_Planskizze_.png
# Skipping duplicate file Zeichen_458_Planskizze_.png
# Skipping duplicate file Zeichen_458_Planskizze_.png
# Downloaded Zeichen_457.2_Ende_der_Umleitung_.png
# Skipping duplicate file Zeichen_457.2_Ende_der_Umleitung_.png
# Skipping duplicate file Zeichen_457.2_Ende_der_Umleitung_.png
# Downloaded Zeichen_455.2_Ende_der_Umleitung.png
# Skipping duplicate file Zeichen_455.2_Ende_der_Umleitung.png
# Skipping duplicate file Zeichen_455.2_Ende_der_Umleitung.png
# Downloaded Zeichen_460_Bedarfs­umleitung.png
# Skipping duplicate file Zeichen_460_Bedarfs­umleitung.png
# Skipping duplicate file Zeichen_460_Bedarfs­umleitung.png
# Downloaded Zeichen_466_Weiterführende_Bedarfsumleitung.png
# Skipping duplicate file Zeichen_466_Weiterführende_Bedarfsumleitung.png
# Skipping duplicate file Zeichen_466_Weiterführende_Bedarfsumleitung.png
# Downloaded Zeichen_467.1_Umlenkungspfeil_(Strecken­empfehlung)_.png
# Skipping duplicate file Zeichen_467.1_Umlenkungspfeil_(Strecken­empfehlung)_.png
# Skipping duplicate file Zeichen_467.1_Umlenkungspfeil_(Strecken­empfehlung)_.png
# Downloaded Zeichen_467.2_Umlenkungspfeil_Ende_(Ende_einer_Strecken­empfehlung).png
# Skipping duplicate file Zeichen_467.2_Umlenkungspfeil_Ende_(Ende_einer_Strecken­empfehlung).png
# Skipping duplicate file Zeichen_467.2_Umlenkungspfeil_Ende_(Ende_einer_Strecken­empfehlung).png
# Downloaded Zeichen_501_Überleitungstafel_-_ohne_Gegenverkehr.png
# Skipping duplicate file Zeichen_501_Überleitungstafel_-_ohne_Gegenverkehr.png
# Skipping duplicate file Zeichen_501_Überleitungstafel_-_ohne_Gegenverkehr.png
# Downloaded Zeichen_531_Einengungstafel_-_ohne_Gegenverkehr_.png
# Skipping duplicate file Zeichen_531_Einengungstafel_-_ohne_Gegenverkehr_.png
# Skipping duplicate file Zeichen_531_Einengungstafel_-_ohne_Gegenverkehr_.png
# Downloaded Zeichen_590_Blockumfahrung_.png
# Skipping duplicate file Zeichen_590_Blockumfahrung_.png
# Skipping duplicate file Zeichen_590_Blockumfahrung_.png
# Downloaded Zeichen_600_Absperrschranke.png
# Skipping duplicate file Zeichen_600_Absperrschranke.png
# Skipping duplicate file Zeichen_600_Absperrschranke.png
# Downloaded Zeichen_605_Leitbake__Pfeilbake.png
# Skipping duplicate file Zeichen_605_Leitbake__Pfeilbake.png
# Skipping duplicate file Zeichen_605_Leitbake__Pfeilbake.png
# Downloaded Zeichen_605_Leitbake__Schraffen­bake.png
# Skipping duplicate file Zeichen_605_Leitbake__Schraffen­bake.png
# Skipping duplicate file Zeichen_605_Leitbake__Schraffen­bake.png
# Downloaded Zeichen_628_Leitschwelle_mit_Pfeilbake.png
# Skipping duplicate file Zeichen_628_Leitschwelle_mit_Pfeilbake.png
# Skipping duplicate file Zeichen_628_Leitschwelle_mit_Pfeilbake.png
# Downloaded Zeichen_628_Leitschwelle_mit_Schraffen­bake.png
# Skipping duplicate file Zeichen_628_Leitschwelle_mit_Schraffen­bake.png
# Skipping duplicate file Zeichen_628_Leitschwelle_mit_Schraffen­bake.png
# Downloaded Zeichen_629_Leitbord_mit_Pfeilbake_.png
# Skipping duplicate file Zeichen_629_Leitbord_mit_Pfeilbake_.png
# Skipping duplicate file Zeichen_629_Leitbord_mit_Pfeilbake_.png
# Downloaded Zeichen_629_Leitbord_mit_Schraffen­bake.png
# Skipping duplicate file Zeichen_629_Leitbord_mit_Schraffen­bake.png
# Skipping duplicate file Zeichen_629_Leitbord_mit_Schraffen­bake.png
# Downloaded Zeichen_610_Leitkegel_.png
# Skipping duplicate file Zeichen_610_Leitkegel_.png
# Skipping duplicate file Zeichen_610_Leitkegel_.png
# Downloaded Zeichen_615_Fahrbare_Absperrtafel_.png
# Skipping duplicate file Zeichen_615_Fahrbare_Absperrtafel_.png
# Skipping duplicate file Zeichen_615_Fahrbare_Absperrtafel_.png
# Downloaded Zeichen_616_Fahrbare_Absperrtafel_mit_Blinkpfeil.png
# Skipping duplicate file Zeichen_616_Fahrbare_Absperrtafel_mit_Blinkpfeil.png
# Skipping duplicate file Zeichen_616_Fahrbare_Absperrtafel_mit_Blinkpfeil.png
# Downloaded Zeichen_625_Richtungstafel_in_Kurven.png
# Skipping duplicate file Zeichen_625_Richtungstafel_in_Kurven.png
# Skipping duplicate file Zeichen_625_Richtungstafel_in_Kurven.png
# Downloaded Zeichen_626_Leitplatte_.png
# Skipping duplicate file Zeichen_626_Leitplatte_.png
# Skipping duplicate file Zeichen_626_Leitplatte_.png
# Downloaded Zeichen_627_Leitmal_.png
# Skipping duplicate file Zeichen_627_Leitmal_.png
# Skipping duplicate file Zeichen_627_Leitmal_.png
# Downloaded Zeichen_620_Leitpfosten_(links)_.png
# Skipping duplicate file Zeichen_620_Leitpfosten_(links)_.png
# Skipping duplicate file Zeichen_620_Leitpfosten_(links)_.png
# Downloaded Zeichen_620_Leitpfosten_(rechts).png
# Skipping duplicate file Zeichen_620_Leitpfosten_(rechts).png
# Skipping duplicate file Zeichen_620_Leitpfosten_(rechts).png
# Downloaded Zeichen_630_Parkwarntafel.png
# Skipping duplicate file Zeichen_630_Parkwarntafel.png
# Skipping duplicate file Zeichen_630_Parkwarntafel.png
# Downloaded Zeichen_720_Grünpfeilschild.png
# Skipping duplicate file Zeichen_720_Grünpfeilschild.png
# Skipping duplicate file Zeichen_720_Grünpfeilschild.png
# Downloaded Zeichen_721_Grünpfeilschild_mit_Beschränkung_auf_den_Radverkehr.png
# Skipping duplicate file Zeichen_721_Grünpfeilschild_mit_Beschränkung_auf_den_Radverkehr.png
# Skipping duplicate file Zeichen_721_Grünpfeilschild_mit_Beschränkung_auf_den_Radverkehr.png
# Downloaded Zeichen_1000-32_Radverkehr_kreuzt_von_links_und_rechts.png
# Skipping duplicate file Zeichen_1000-32_Radverkehr_kreuzt_von_links_und_rechts.png
# Skipping duplicate file Zeichen_1000-32_Radverkehr_kreuzt_von_links_und_rechts.png
# Downloaded Zeichen_1001-31_Auf_3_km.png
# Skipping duplicate file Zeichen_1001-31_Auf_3_km.png
# Skipping duplicate file Zeichen_1001-31_Auf_3_km.png
# Downloaded Zeichen_1001-31_Auf_2_km_.png
# Skipping duplicate file Zeichen_1001-31_Auf_2_km_.png
# Skipping duplicate file Zeichen_1001-31_Auf_2_km_.png
# Downloaded Zeichen_1002-10_Verlauf_der_Vorfahrt­straße_an_Kreuzungen_-_von_unten_nach_links.png
# Skipping duplicate file Zeichen_1002-10_Verlauf_der_Vorfahrt­straße_an_Kreuzungen_-_von_unten_nach_links.png
# Skipping duplicate file Zeichen_1002-10_Verlauf_der_Vorfahrt­straße_an_Kreuzungen_-_von_unten_nach_links.png
# Downloaded Zeichen_1002-21_Verlauf_der_Vorfahrt­straße_an_Kreuzungen_-_von_oben_nach_rechts.png
# Skipping duplicate file Zeichen_1002-21_Verlauf_der_Vorfahrt­straße_an_Kreuzungen_-_von_oben_nach_rechts.png
# Skipping duplicate file Zeichen_1002-21_Verlauf_der_Vorfahrt­straße_an_Kreuzungen_-_von_oben_nach_rechts.png
# Downloaded Zeichen_1004-30_Entfernungs­angabe_in_m.png
# Skipping duplicate file Zeichen_1004-30_Entfernungs­angabe_in_m.png
# Skipping duplicate file Zeichen_1004-30_Entfernungs­angabe_in_m.png
# Downloaded Zeichen_1004-32_Stop_in_100_m_.png
# Skipping duplicate file Zeichen_1004-32_Stop_in_100_m_.png
# Skipping duplicate file Zeichen_1004-32_Stop_in_100_m_.png
# Downloaded Zeichen_1005-30_Reißverschluss_erst_in_…_m_.png
# Skipping duplicate file Zeichen_1005-30_Reißverschluss_erst_in_…_m_.png
# Skipping duplicate file Zeichen_1005-30_Reißverschluss_erst_in_…_m_.png
# Downloaded Zeichen_1010-56_Straßenbahn_.png
# Skipping duplicate file Zeichen_1010-56_Straßenbahn_.png
# Skipping duplicate file Zeichen_1010-56_Straßenbahn_.png
# Downloaded Zeichen_1013-52_Besondere_Hinweise_zur_Seiten­streifen­freigabe_Ende_in_..._m.png
# Skipping duplicate file Zeichen_1013-52_Besondere_Hinweise_zur_Seiten­streifen­freigabe_Ende_in_..._m.png
# Skipping duplicate file Zeichen_1013-52_Besondere_Hinweise_zur_Seiten­streifen­freigabe_Ende_in_..._m.png
# Downloaded Zeichen_1020-11_Schwerbehinderte_mit_Parkausweis_Nr._…_frei.png
# Skipping duplicate file Zeichen_1020-11_Schwerbehinderte_mit_Parkausweis_Nr._…_frei.png
# Skipping duplicate file Zeichen_1020-11_Schwerbehinderte_mit_Parkausweis_Nr._…_frei.png
# Downloaded Zeichen_1020-13_Inline-Skaten_und_Rollschuhfahren_zugelassen.png
# Skipping duplicate file Zeichen_1020-13_Inline-Skaten_und_Rollschuhfahren_zugelassen.png
# Skipping duplicate file Zeichen_1020-13_Inline-Skaten_und_Rollschuhfahren_zugelassen.png
# Downloaded Zeichen_1020-32_Bewohner_mit_Parkausweis_Nr._…_frei_.png
# Skipping duplicate file Zeichen_1020-32_Bewohner_mit_Parkausweis_Nr._…_frei_.png
# Skipping duplicate file Zeichen_1020-32_Bewohner_mit_Parkausweis_Nr._…_frei_.png
# Downloaded Zeichen_1022-10_Radverkehr_frei_.png
# Skipping duplicate file Zeichen_1022-10_Radverkehr_frei_.png
# Skipping duplicate file Zeichen_1022-10_Radverkehr_frei_.png
# Downloaded Zeichen_(1022-12_und_1024-10)_KFZ_frei.png
# Skipping duplicate file Zeichen_(1022-12_und_1024-10)_KFZ_frei.png
# Skipping duplicate file Zeichen_(1022-12_und_1024-10)_KFZ_frei.png
# Downloaded Zeichen_1022-16_Elektrokleinstfahrzeuge_frei_.png
# Skipping duplicate file Zeichen_1022-16_Elektrokleinstfahrzeuge_frei_.png
# Skipping duplicate file Zeichen_1022-16_Elektrokleinstfahrzeuge_frei_.png
# Downloaded Zeichen_1024-20_Elektrisch_betriebene_Fahrzeuge_frei.png
# Skipping duplicate file Zeichen_1024-20_Elektrisch_betriebene_Fahrzeuge_frei.png
# Skipping duplicate file Zeichen_1024-20_Elektrisch_betriebene_Fahrzeuge_frei.png
# Downloaded Zeichen_1024-21_Carsharingfahrzeuge_frei_.png
# Skipping duplicate file Zeichen_1024-21_Carsharingfahrzeuge_frei_.png
# Skipping duplicate file Zeichen_1024-21_Carsharingfahrzeuge_frei_.png
# Downloaded Zeichen_1024-22_Mehrfachbesetzte_Personenkraftwagen_frei.png
# Skipping duplicate file Zeichen_1024-22_Mehrfachbesetzte_Personenkraftwagen_frei.png
# Skipping duplicate file Zeichen_1024-22_Mehrfachbesetzte_Personenkraftwagen_frei.png
# Downloaded Zeichen_1031_Freistellung_vom_Verkehrs­verbot_nach_§_40_Absatz_1_BImSchG.png
# Skipping duplicate file Zeichen_1031_Freistellung_vom_Verkehrs­verbot_nach_§_40_Absatz_1_BImSchG.png
# Skipping duplicate file Zeichen_1031_Freistellung_vom_Verkehrs­verbot_nach_§_40_Absatz_1_BImSchG.png
# Downloaded Zeichen_1053-33_Massenangabe_-_7,5_t_.png
# Skipping duplicate file Zeichen_1053-33_Massenangabe_-_7,5_t_.png
# Skipping duplicate file Zeichen_1053-33_Massenangabe_-_7,5_t_.png
# Downloaded Zeichen_1053-33_Massenangabe_-_2,8_t.png
# Skipping duplicate file Zeichen_1053-33_Massenangabe_-_2,8_t.png
# Skipping duplicate file Zeichen_1053-33_Massenangabe_-_2,8_t.png
# Downloaded Zeichen_1053-34_Auf_dem_Seiten­streifen.png
# Skipping duplicate file Zeichen_1053-34_Auf_dem_Seiten­streifen.png
# Skipping duplicate file Zeichen_1053-34_Auf_dem_Seiten­streifen.png
# Downloaded Zeichen_1053-35_Bei_Nässe_.png
# Skipping duplicate file Zeichen_1053-35_Bei_Nässe_.png
# Skipping duplicate file Zeichen_1053-35_Bei_Nässe_.png
# Downloaded Zeichen_1053-36_Durchgangsverkehr_.png
# Skipping duplicate file Zeichen_1053-36_Durchgangsverkehr_.png
# Skipping duplicate file Zeichen_1053-36_Durchgangsverkehr_.png
# Downloaded Zeichen_1053-37_Massenangabe_-_12_t.png
# Skipping duplicate file Zeichen_1053-37_Massenangabe_-_12_t.png
# Skipping duplicate file Zeichen_1053-37_Massenangabe_-_12_t.png
# Downloaded Zeichen_1060-31_Auch_auf_dem_Seiten­streifen.png
# Skipping duplicate file Zeichen_1060-31_Auch_auf_dem_Seiten­streifen.png
# Skipping duplicate file Zeichen_1060-31_Auch_auf_dem_Seiten­streifen.png
# Downloaded Zeichen_1060-32_Auch_Kraftomnibusse_und_PKW_mit_Anhängern_(im_Bereich_von_LKW-Kontrollen).png
# Skipping duplicate file Zeichen_1060-32_Auch_Kraftomnibusse_und_PKW_mit_Anhängern_(im_Bereich_von_LKW-Kontrollen).png
# Skipping duplicate file Zeichen_1060-32_Auch_Kraftomnibusse_und_PKW_mit_Anhängern_(im_Bereich_von_LKW-Kontrollen).png
# Downloaded Kraftwagen_und_sonstige_mehr­spurige_Kraftfahrzeuge_.png
# Skipping duplicate file Kraftwagen_und_sonstige_mehr­spurige_Kraftfahrzeuge_.png
# Skipping duplicate file Kraftwagen_und_sonstige_mehr­spurige_Kraftfahrzeuge_.png
# Downloaded Kraft­fahr­zeuge_mit_einem_zuläs­sigen_Gesamt­gewicht_über_3,5_t,_einschließlich_ihrer_Anhänger,_und_Zug­maschinen,_ausgenommen_Personen­kraft­wagen_und_Kraft­omni­busse_.png
# Skipping duplicate file Kraft­fahr­zeuge_mit_einem_zuläs­sigen_Gesamt­gewicht_über_3,5_t,_einschließlich_ihrer_Anhänger,_und_Zug­maschinen,_ausgenommen_Personen­kraft­wagen_und_Kraft­omni­busse_.png
# Skipping duplicate file Kraft­fahr­zeuge_mit_einem_zuläs­sigen_Gesamt­gewicht_über_3,5_t,_einschließlich_ihrer_Anhänger,_und_Zug­maschinen,_ausgenommen_Personen­kraft­wagen_und_Kraft­omni­busse_.png
# Downloaded Radfahrer_.png
# Skipping duplicate file Radfahrer_.png
# Skipping duplicate file Radfahrer_.png
# Downloaded Fahrrad_zum_Transport_von_Gütern_oder_Personen_–_Lastenfahrrad.png
# Skipping duplicate file Fahrrad_zum_Transport_von_Gütern_oder_Personen_–_Lastenfahrrad.png
# Skipping duplicate file Fahrrad_zum_Transport_von_Gütern_oder_Personen_–_Lastenfahrrad.png
# Downloaded Fuß­gänger.png
# Skipping duplicate file Fuß­gänger.png
# Skipping duplicate file Fuß­gänger.png
# Downloaded Reiter_.png
# Skipping duplicate file Reiter_.png
# Skipping duplicate file Reiter_.png
# Downloaded Viehtrieb_.png
# Skipping duplicate file Viehtrieb_.png
# Skipping duplicate file Viehtrieb_.png
# Downloaded Straßenbahn.png
# Skipping duplicate file Straßenbahn.png
# Skipping duplicate file Straßenbahn.png
# Downloaded Kraftomnibus.png
# Skipping duplicate file Kraftomnibus.png
# Skipping duplicate file Kraftomnibus.png
# Downloaded Personen­kraft­wagen_.png
# Skipping duplicate file Personen­kraft­wagen_.png
# Skipping duplicate file Personen­kraft­wagen_.png
# Downloaded Personenkraftwagen_oder_Krafträder_mit_Beiwagen,_die_mit_mindestens_drei_Personen_besetzt_sind_–_Mehrfachbesetzte_Personenkraftwagen.png
# Skipping duplicate file Personenkraftwagen_oder_Krafträder_mit_Beiwagen,_die_mit_mindestens_drei_Personen_besetzt_sind_–_Mehrfachbesetzte_Personenkraftwagen.png
# Skipping duplicate file Personenkraftwagen_oder_Krafträder_mit_Beiwagen,_die_mit_mindestens_drei_Personen_besetzt_sind_–_Mehrfachbesetzte_Personenkraftwagen.png
# Downloaded Personen­kraft­wagen_mit_An­hänger.png
# Skipping duplicate file Personen­kraft­wagen_mit_An­hänger.png
# Skipping duplicate file Personen­kraft­wagen_mit_An­hänger.png
# Downloaded Lastkraftwagen_mit_Anhänger_.png
# Skipping duplicate file Lastkraftwagen_mit_Anhänger_.png
# Skipping duplicate file Lastkraftwagen_mit_Anhänger_.png
# Downloaded Wohnmobil.png
# Skipping duplicate file Wohnmobil.png
# Skipping duplicate file Wohnmobil.png
# Downloaded Kraft­fahr­zeuge_und_Züge,_die_nicht_schneller_als_25_kmh_fahren_können_oder_dürfen.png
# Skipping duplicate file Kraft­fahr­zeuge_und_Züge,_die_nicht_schneller_als_25_kmh_fahren_können_oder_dürfen.png
# Skipping duplicate file Kraft­fahr­zeuge_und_Züge,_die_nicht_schneller_als_25_kmh_fahren_können_oder_dürfen.png
# Downloaded Krafträder,_auch_mit_Beiwagen,_Klein­kraft­räder_und_Mofas_.png
# Skipping duplicate file Krafträder,_auch_mit_Beiwagen,_Klein­kraft­räder_und_Mofas_.png
# Skipping duplicate file Krafträder,_auch_mit_Beiwagen,_Klein­kraft­räder_und_Mofas_.png
# Downloaded Mofas.png
# Skipping duplicate file Mofas.png
# Skipping duplicate file Mofas.png
# Downloaded Einsitzige_zweirädrige_Kleinkrafträder_mit_elektrischem_Antrieb,_der_sich_bei_einer_Geschwindigkeit_von_mehr_als_25_kmh_selbsttätig_abschaltet_−_E-Bikes_−.png
# Skipping duplicate file Einsitzige_zweirädrige_Kleinkrafträder_mit_elektrischem_Antrieb,_der_sich_bei_einer_Geschwindigkeit_von_mehr_als_25_kmh_selbsttätig_abschaltet_−_E-Bikes_−.png
# Skipping duplicate file Einsitzige_zweirädrige_Kleinkrafträder_mit_elektrischem_Antrieb,_der_sich_bei_einer_Geschwindigkeit_von_mehr_als_25_kmh_selbsttätig_abschaltet_−_E-Bikes_−.png
# Downloaded Elektrokleinstfahrzeug_im_Sinne_der_Elektrokleinstfahrzeuge-Verordnung_(ekFV).png
# Skipping duplicate file Elektrokleinstfahrzeug_im_Sinne_der_Elektrokleinstfahrzeuge-Verordnung_(ekFV).png
# Skipping duplicate file Elektrokleinstfahrzeug_im_Sinne_der_Elektrokleinstfahrzeuge-Verordnung_(ekFV).png
# Downloaded Gespannfuhrwerke_.png
# Skipping duplicate file Gespannfuhrwerke_.png
# Skipping duplicate file Gespannfuhrwerke_.png
# Downloaded Schnee-_oder_Eisglätte.png
# Skipping duplicate file Schnee-_oder_Eisglätte.png
# Skipping duplicate file Schnee-_oder_Eisglätte.png
# Downloaded Steinschlag_.png
# Skipping duplicate file Steinschlag_.png
# Skipping duplicate file Steinschlag_.png
# Downloaded Splitt,_Schotter_.png
# Skipping duplicate file Splitt,_Schotter_.png
# Skipping duplicate file Splitt,_Schotter_.png
# Downloaded _Bewegliche_Brücke.png
# Skipping duplicate file _Bewegliche_Brücke.png
# Skipping duplicate file _Bewegliche_Brücke.png
# Downloaded Ufer_.png
# Skipping duplicate file Ufer_.png
# Skipping duplicate file Ufer_.png
# Downloaded Fußgänger­überweg_.png
# Skipping duplicate file Fußgänger­überweg_.png
# Skipping duplicate file Fußgänger­überweg_.png
# Downloaded Amphibien­wanderung.png
# Skipping duplicate file Amphibien­wanderung.png
# Skipping duplicate file Amphibien­wanderung.png
# Downloaded Unzureichendes_Lichtraum­profil.png
# Skipping duplicate file Unzureichendes_Lichtraum­profil.png
# Skipping duplicate file Unzureichendes_Lichtraum­profil.png
# Downloaded Flugbetrieb.png
# Skipping duplicate file Flugbetrieb.png
# Skipping duplicate file Flugbetrieb.png
# Downloaded elektrisch_betriebenes_Fahrzeug_.png
# Skipping duplicate file elektrisch_betriebenes_Fahrzeug_.png
# Skipping duplicate file elektrisch_betriebenes_Fahrzeug_.png
# Downloaded Carsharing_.png
# Skipping duplicate file Carsharing_.png
# Skipping duplicate file Carsharing_.png
# Downloaded Carsharing-Plakette_.png
# Skipping duplicate file Carsharing-Plakette_.png
# Skipping duplicate file Carsharing-Plakette_.png
# Downloaded Autobahn­ausfahrt.png
# Skipping duplicate file Autobahn­ausfahrt.png
# Skipping duplicate file Autobahn­ausfahrt.png
# Downloaded Autobahnkreuz_.png
# Skipping duplicate file Autobahnkreuz_.png
# Skipping duplicate file Autobahnkreuz_.png

# %%
from zipfile import ZipFile

# Name of the zip file
zip_filename = "verkehrszeichen_images.zip"

# Create a zip file
with ZipFile(zip_filename, 'w') as zipf:
    for filename in os.listdir('.'):
        if filename.endswith('.png'):
            zipf.write(filename)

# Download the zip file
from google.colab import files
files.download(zip_filename)
